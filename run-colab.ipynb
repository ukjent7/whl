# %%
# !wget "https://github.com/ukjent7/whl/releases/download/baidu/llama-colab.zip" && unzip llama-colab.zip
# !wget "https://github.com/openziti/zrok/releases/download/v2.0.2/zrok_2.0.2_linux_amd64.tar.gz" && tar -xzf zrok_2.0.2_linux_amd64.tar.gz

# %%
# !wget "https://huggingface.co/ZIBONF/TEST/resolve/main/QWEN3-iq4xs.gguf"

# %%
#每次都需要重新运行
# !chmod +x ./llama-server
# !chmod +x ./zrok2
# !./zrok2 enable key by https://api-v2.zrok.io/

# %%
# !./llama-server \
  -m "/content/drive/MyDrive/Colab Notebooks/QWEN3-iq4xs.gguf" \
  -np 1 \
  -t 2 \
  --verbosity 2 \
  --no-cache-prompt \
  --host 0.0.0.0 \
  --port 8088 \
  --no-webui & \
./zrok2 share public localhost:8088
