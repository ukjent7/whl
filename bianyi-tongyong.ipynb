# %%
# !git clone https://gh-proxy.org/https://github.com/ggml-org/llama.cpp
# %cd llama.cpp

# %%
# !cmake -B build -DGGML_CUDA=ON -DBUILD_SHARED_LIBS=OFF -DCMAKE_CUDA_ARCHITECTURES=70

# %%
# 开始编译 (使用所有可用核心)
# !cmake --build build --config Release  --target llama-server -j 2

# %%
#编译位置/build/bin/
